# %% [markdown]
# <a href="https://colab.research.google.com/github/Nifty0x/web-scraper/blob/main/Insights_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install undetected-chromedriver
# !apt-get update
# !apt install -y chromium-browser xvfb

import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import time
import os

def setup_driver():
    """Setup undetected-chromedriver with appropriate options"""
    options = uc.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')

    try:
        driver = uc.Chrome(options=options)
        return driver
    except Exception as e:
        print(f"Error setting up driver: {e}")
        return None

def extract_claim_urls(base_url):
    """Extract claim URLs from the specified page"""
    print("Initializing driver...")
    driver = setup_driver()

    if not driver:
        print("Failed to initialize driver")
        return []

    claim_urls = []

    try:
        print(f"\nAccessing {base_url}...")
        driver.get(base_url)

        # Wait for page to load
        print("Waiting for page to load...")
        time.sleep(15)  # Increased wait time

        # Find all links
        print("Searching for links...")
        links = driver.find_elements(By.TAG_NAME, "a")
        print(f"Found {len(links)} total links")

        # Filter for claim URLs
        for link in links:
            try:
                href = link.get_attribute('href')
                if href and 'claim-project' in href:
                    claim_urls.append(href)
                    print(f"Found claim URL: {href}")
            except Exception as e:
                print(f"Error processing link: {e}")

    except Exception as e:
        print(f"Error accessing page: {e}")

    finally:
        try:
            driver.quit()
        except:
            pass

    return claim_urls

# Main execution
print("Setting up the environment...")
base_url = "https://insights.rwa.io"
print("\nStarting URL extraction...")

try:
    claim_urls = extract_claim_urls(base_url)

    print("\nSummary of found claim URLs:")
    if claim_urls:
        for url in claim_urls:
            print(url)
    else:
        print("No claim URLs found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Collecting undetected-chromedriver
#   Downloading undetected-chromedriver-3.5.5.tar.gz (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: selenium>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from undetected-chromedriver) (4.25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from undetected-chromedriver) (2.32.3)
# Collecting websockets (from undetected-chromedriver)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium>=4.9.0->undetected-chromedriver) (2.2.3)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium>=4.9.0->undetected-chromedriver) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium>=4.9.0->undetected-chromedriver) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium>=4.9.0->undetected-chromedriver) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.10/dist-packages (from selenium>=4.9.0->undetected-chromedriver) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.10/dist-packages (from selenium>=4.9.0->undetected-chromedriver) (1.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->undetected-chromedriver) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->undetected-chromedriver) (3.10)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium>=4.9.0->undetected-chromedriver) (24.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium>=4.9.0->undetected-chromedriver) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium>=4.9.0->undetected-chromedriver) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium>=4.9.0->undetected-chromedriver) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium>=4.9.0->undetected-chromedriver) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium>=4.9.0->undetected-chromedriver) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium>=4.9.0->undetected-chromedriver) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium>=4.9.0->undetected-chromedriver) (0.14.0)
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 11.5 MB/s eta 0:00:00
# Building wheels for collected packages: undetected-chromedriver
#   Building wheel for undetected-chromedriver (setup.py) ... done
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.5.5-py3-none-any.whl size=47048 sha256=0dfc10a171e0a55f077c930642a049f0a15a685c09a3edb1be24a28dc3d2264b
#   Stored in directory: /root/.cache/pip/wheels/cf/a1/db/e1275b6f7259aacd6b045f8bfcb1fcbc93827a3916ba55d5b7
# Successfully built undetected-chromedriver
# Installing collected packages: websockets, undetected-chromedriver
# Successfully installed undetected-chromedriver-3.5.5 websockets-13.1
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Ign:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-browser is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 52 not upgraded.
# Need to get 7,813 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.11 [28.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.11 [863 kB]
# Fetched 7,813 kB in 2s (4,150 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 124081 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.11_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.11_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Setting up the environment...
#
# Starting URL extraction...
# Initializing driver...
# Error setting up driver: Message: session not created: cannot connect to chrome at 127.0.0.1:57809
# from chrome not reachable
# Stacktrace:
# #0 0x5c271455a13a <unknown>
# #1 0x5c27140752bd <unknown>
# #2 0x5c27140614bf <unknown>
# #3 0x5c27140b056c <unknown>
# #4 0x5c27140a6392 <unknown>
# #5 0x5c27140f2156 <unknown>
# #6 0x5c27140f17a6 <unknown>
# #7 0x5c27140e5db3 <unknown>
# #8 0x5c27140b4c10 <unknown>
# #9 0x5c27140b5bee <unknown>
# #10 0x5c27145263cb <unknown>
# #11 0x5c271452a368 <unknown>
# #12 0x5c2714513eec <unknown>
# #13 0x5c271452aee7 <unknown>
# #14 0x5c27144f913f <unknown>
# #15 0x5c2714548858 <unknown>
# #16 0x5c2714548a20 <unknown>
# #17 0x5c2714558fb6 <unknown>
# #18 0x7ba0e1e89ac3 <unknown>
#
# Failed to initialize driver
#
# Summary of found claim URLs:
# No claim URLs found.

# %%
# Install required packages
# !pip install requests beautifulsoup4

import requests
from bs4 import BeautifulSoup
import re
import time

def extract_claim_urls(base_url):
    """Extract claim URLs using requests and BeautifulSoup"""
    # Headers to mimic a browser request
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    claim_urls = []

    try:
        print(f"Accessing {base_url}...")
        response = requests.get(base_url, headers=headers)
        response.raise_for_status()  # Raise an exception for bad status codes

        print("Parsing page content...")
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all links
        links = soup.find_all('a', href=True)
        print(f"Found {len(links)} total links")

        # Pattern to match claim project URLs
        claim_pattern = re.compile(r'claim-project')

        # Filter for claim URLs
        for link in links:
            href = link['href']
            if claim_pattern.search(href):
                # Make sure we have absolute URLs
                full_url = href if href.startswith('http') else f"{base_url.rstrip('/')}/{href.lstrip('/')}"
                claim_urls.append(full_url)
                print(f"Found claim URL: {full_url}")

        # Also try to find any data-attributes or other elements that might contain the URLs
        elements = soup.find_all(attrs={"data-href": claim_pattern})
        for element in elements:
            href = element.get('data-href')
            if href:
                full_url = href if href.startswith('http') else f"{base_url.rstrip('/')}/{href.lstrip('/')}"
                if full_url not in claim_urls:
                    claim_urls.append(full_url)
                    print(f"Found claim URL from data attribute: {full_url}")

    except requests.exceptions.RequestException as e:
        print(f"Error accessing the page: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

    return claim_urls

def scan_multiple_pages(base_url):
    """Scan multiple pages including potential subpages"""
    all_urls = set()  # Using a set to avoid duplicates

    # List of paths to check
    paths_to_check = [
        "",  # Root page
        "/insights",
        "/project",
        "/list-your-project/claim-project",
        "/browse",
        "/search"
    ]

    for path in paths_to_check:
        url = f"{base_url.rstrip('/')}/{path.lstrip('/')}"
        print(f"\nChecking path: {url}")
        urls = extract_claim_urls(url)
        all_urls.update(urls)
        time.sleep(2)  # Small delay between requests

    return list(all_urls)

# Main execution
print("Starting URL extraction...")
base_url = "https://insights.rwa.io"

try:
    claim_urls = scan_multiple_pages(base_url)

    print("\nSummary of all found claim URLs:")
    if claim_urls:
        for url in sorted(claim_urls):
            print(url)
        print(f"\nTotal unique claim URLs found: {len(claim_urls)}")
    else:
        print("No claim URLs found.")

        # Print the page content for debugging
        print("\nTrying to fetch and print page source for debugging...")
        response = requests.get(base_url)
        print(f"Status Code: {response.status_code}")
        print("\nFirst 1000 characters of page source:")
        print(response.text[:1000])

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Starting URL extraction...
#
# Checking path: https://insights.rwa.io/
# Accessing https://insights.rwa.io/...
# Parsing page content...
# Found 46 total links
#
# Checking path: https://insights.rwa.io/insights
# Accessing https://insights.rwa.io/insights...
# Error accessing the page: 404 Client Error: Not Found for url: https://insights.rwa.io/insights
#
# Checking path: https://insights.rwa.io/project
# Accessing https://insights.rwa.io/project...
# Error accessing the page: 404 Client Error: Not Found for url: https://insights.rwa.io/project
#
# Checking path: https://insights.rwa.io/list-your-project/claim-project
# Accessing https://insights.rwa.io/list-your-project/claim-project...
# Parsing page content...
# Found 1 total links
#
# Checking path: https://insights.rwa.io/browse
# Accessing https://insights.rwa.io/browse...
# Error accessing the page: 404 Client Error: Not Found for url: https://insights.rwa.io/browse
#
# Checking path: https://insights.rwa.io/search
# Accessing https://insights.rwa.io/search...
# Error accessing the page: 404 Client Error: Not Found for url: https://insights.rwa.io/search
#
# Summary of all found claim URLs:
# No claim URLs found.
#
# Trying to fetch and print page source for debugging...
# Status Code: 200
#
# First 1000 characters of page source:
# <!DOCTYPE html><html lang="en" class="bg-background-gradient"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="preload" href="/_next/static/media/02edef4d0edfad6d-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/045832894acda0e9-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/120a5a1920781bd0-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/6ebb97b5c9fa4e03-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/c714540e49ad5111-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/da897b99eb1fe4a1-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="stylesheet" href="/_next/static/css/e6ef32a7b29a7f24.css" data-precedence="next"/><link rel="stylesheet" href="/_next/sta

# %%
import requests
from bs4 import BeautifulSoup
import json

def get_project_claim_url(project_slug):
    """Generate claim URL for a specific project"""
    return f"https://insights.rwa.io/list-your-project/claim-project?slug={project_slug}"

def check_url_exists(url):
    """Check if a URL exists and returns content"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers)
        return response.status_code == 200, response.text
    except:
        return False, None

def extract_project_slugs():
    """Extract project slugs from the main page"""
    url = "https://insights.rwa.io"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    try:
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Look for any script tags containing __NEXT_DATA__
        scripts = soup.find_all('script', {'id': '__NEXT_DATA__'})

        slugs = set()
        for script in scripts:
            try:
                data = json.loads(script.string)
                # You might need to adjust this path based on your actual data structure
                if 'props' in data and 'pageProps' in data['props']:
                    # Extract project data - adjust this based on your actual data structure
                    projects_data = data['props']['pageProps'].get('projects', [])
                    for project in projects_data:
                        if 'slug' in project:
                            slugs.add(project['slug'])
            except:
                continue

        return list(slugs)
    except Exception as e:
        print(f"Error extracting project slugs: {e}")
        return []

def main():
    print("Starting URL extraction...")

    # First try the known project "domani"
    domani_url = get_project_claim_url("domani")
    exists, content = check_url_exists(domani_url)
    if exists:
        print(f"Found valid claim URL: {domani_url}")

    # Then try to extract other project slugs
    print("\nAttempting to extract other project slugs...")
    slugs = extract_project_slugs()

    if slugs:
        print(f"\nFound {len(slugs)} project slugs")
        for slug in slugs:
            url = get_project_claim_url(slug)
            exists, _ = check_url_exists(url)
            if exists:
                print(f"Valid claim URL: {url}")
    else:
        print("No additional project slugs found")

    print("\nTrying direct URL construction for 'domani':")
    direct_urls = [
        "https://insights.rwa.io/list-your-project/claim-project?slug=domani",
        "https://insights.rwa.io/list-your-project/claim-project/domani"
    ]

    for url in direct_urls:
        exists, _ = check_url_exists(url)
        if exists:
            print(f"Valid URL found: {url}")

if __name__ == "__main__":
    main()
# Out:
# Starting URL extraction...
# Found valid claim URL: https://insights.rwa.io/list-your-project/claim-project?slug=domani
#
# Attempting to extract other project slugs...
# No additional project slugs found
#
# Trying direct URL construction for 'domani':
# Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=domani
# Valid URL found: https://insights.rwa.io/list-your-project/claim-project/domani

# %%
import requests
import time
from urllib.parse import quote

def check_url_exists(url):
    """Check if a URL exists and returns content"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers)
        return response.status_code == 200, response.text
    except Exception as e:
        print(f"Error checking URL {url}: {e}")
        return False, None

def get_claim_urls(slug):
    """Generate possible claim URLs for a given slug"""
    base_url = "https://insights.rwa.io/list-your-project/claim-project"
    encoded_slug = quote(slug.lower())
    return [
        f"{base_url}?slug={encoded_slug}",
        f"{base_url}/{encoded_slug}"
    ]

def check_project_slug(slug):
    """Check all possible URL patterns for a given project slug"""
    print(f"\nChecking URLs for project: {slug}")
    valid_urls = []

    urls = get_claim_urls(slug)
    for url in urls:
        exists, _ = check_url_exists(url)
        if exists:
            valid_urls.append(url)
            print(f"✓ Valid URL found: {url}")
        else:
            print(f"✗ Invalid URL: {url}")

    return valid_urls

def main():
    # List of potential project slugs to check
    # Starting with known tokens and common variations
    project_slugs = [
        "domani",
        "DEXTF",
        "dextf",
        "defi-exchange-traded-funds",
        "goldfinch",
        "centrifuge",
        "maple",
        "maple-finance",
        "rwa-market",
        "rwa",
        "blocktower",
        "blocktower-credit",
        "real-world-assets",
        "ondo",
        "ondo-finance",
        "mcp",
        "monetalis",
        "monetalis-clydesdale"
    ]

    print("Starting comprehensive URL check...")
    all_valid_urls = {}

    for slug in project_slugs:
        valid_urls = check_project_slug(slug)
        if valid_urls:
            all_valid_urls[slug] = valid_urls
        time.sleep(1)  # Be nice to the server

    print("\n=== Summary of Results ===")
    if all_valid_urls:
        print(f"\nFound {len(all_valid_urls)} projects with valid claim URLs:")
        for slug, urls in all_valid_urls.items():
            print(f"\nProject: {slug}")
            for url in urls:
                print(f"  {url}")
    else:
        print("No valid claim URLs found beyond the original domani project.")

    print("\nNote: This list may not be exhaustive. Consider checking specific project names or tokens you're interested in.")

if __name__ == "__main__":
    main()
# Out:
# Starting comprehensive URL check...
#
# Checking URLs for project: domani
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=domani
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/domani
#
# Checking URLs for project: DEXTF
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=dextf
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/dextf
#
# Checking URLs for project: dextf
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=dextf
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/dextf
#
# Checking URLs for project: defi-exchange-traded-funds
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=defi-exchange-traded-funds
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/defi-exchange-traded-funds
#
# Checking URLs for project: goldfinch
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=goldfinch
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/goldfinch
#
# Checking URLs for project: centrifuge
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=centrifuge
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/centrifuge
#
# Checking URLs for project: maple
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=maple
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/maple
#
# Checking URLs for project: maple-finance
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=maple-finance
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/maple-finance
#
# Checking URLs for project: rwa-market
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=rwa-market
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/rwa-market
#
# Checking URLs for project: rwa
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=rwa
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/rwa
#
# Checking URLs for project: blocktower
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=blocktower
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/blocktower
#
# Checking URLs for project: blocktower-credit
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=blocktower-credit
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/blocktower-credit
#
# Checking URLs for project: real-world-assets
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=real-world-assets
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/real-world-assets
#
# Checking URLs for project: ondo
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=ondo
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/ondo
#
# Checking URLs for project: ondo-finance
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=ondo-finance
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/ondo-finance
#
# Checking URLs for project: mcp
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=mcp
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/mcp
#
# Checking URLs for project: monetalis
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=monetalis
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/monetalis
#
# Checking URLs for project: monetalis-clydesdale
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project?slug=monetalis-clydesdale
# ✓ Valid URL found: https://insights.rwa.io/list-your-project/claim-project/monetalis-clydesdale
#
# === Summary of Results ===
#
# Found 18 projects with valid claim URLs:
#
# Project: domani
#   https://insights.rwa.io/list-your-project/claim-project?slug=domani
#   https://insights.rwa.io/list-your-project/claim-project/domani
#
# Project: DEXTF
#   https://insights.rwa.io/list-your-project/claim-project?slug=dextf
#   https://insights.rwa.io/list-your-project/claim-project/dextf
#
# Project: dextf
#   https://insights.rwa.io/list-your-project/claim-project?slug=dextf
#   https://insights.rwa.io/list-your-project/claim-project/dextf
#
# Project: defi-exchange-traded-funds
#   https://insights.rwa.io/list-your-project/claim-project?slug=defi-exchange-traded-funds
#   https://insights.rwa.io/list-your-project/claim-project/defi-exchange-traded-funds
#
# Project: goldfinch
#   https://insights.rwa.io/list-your-project/claim-project?slug=goldfinch
#   https://insights.rwa.io/list-your-project/claim-project/goldfinch
#
# Project: centrifuge
#   https://insights.rwa.io/list-your-project/claim-project?slug=centrifuge
#   https://insights.rwa.io/list-your-project/claim-project/centrifuge
#
# Project: maple
#   https://insights.rwa.io/list-your-project/claim-project?slug=maple
#   https://insights.rwa.io/list-your-project/claim-project/maple
#
# Project: maple-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=maple-finance
#   https://insights.rwa.io/list-your-project/claim-project/maple-finance
#
# Project: rwa-market
#   https://insights.rwa.io/list-your-project/claim-project?slug=rwa-market
#   https://insights.rwa.io/list-your-project/claim-project/rwa-market
#
# Project: rwa
#   https://insights.rwa.io/list-your-project/claim-project?slug=rwa
#   https://insights.rwa.io/list-your-project/claim-project/rwa
#
# Project: blocktower
#   https://insights.rwa.io/list-your-project/claim-project?slug=blocktower
#   https://insights.rwa.io/list-your-project/claim-project/blocktower
#
# Project: blocktower-credit
#   https://insights.rwa.io/list-your-project/claim-project?slug=blocktower-credit
#   https://insights.rwa.io/list-your-project/claim-project/blocktower-credit
#
# Project: real-world-assets
#   https://insights.rwa.io/list-your-project/claim-project?slug=real-world-assets
#   https://insights.rwa.io/list-your-project/claim-project/real-world-assets
#
# Project: ondo
#   https://insights.rwa.io/list-your-project/claim-project?slug=ondo
#   https://insights.rwa.io/list-your-project/claim-project/ondo
#
# Project: ondo-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=ondo-finance
#   https://insights.rwa.io/list-your-project/claim-project/ondo-finance
#
# Project: mcp
#   https://insights.rwa.io/list-your-project/claim-project?slug=mcp
#   https://insights.rwa.io/list-your-project/claim-project/mcp
#
# Project: monetalis
#   https://insights.rwa.io/list-your-project/claim-project?slug=monetalis
#   https://insights.rwa.io/list-your-project/claim-project/monetalis
#
# Project: monetalis-clydesdale
#   https://insights.rwa.io/list-your-project/claim-project?slug=monetalis-clydesdale
#   https://insights.rwa.io/list-your-project/claim-project/monetalis-clydesdale
#
# Note: This list may not be exhaustive. Consider checking specific project names or tokens you're interested in.

# %%
import requests
import time
import json
import xml.etree.ElementTree as ET
from xml.dom import minidom
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed

def check_url_exists(url, timeout=10):
    """Check if a URL exists"""
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    try:
        response = requests.get(url, headers=headers, timeout=timeout)
        return response.status_code == 200
    except Exception:
        return False

def check_project(slug):
    """Check both URL patterns for a project"""
    base_url = "https://insights.rwa.io/list-your-project/claim-project"
    urls = [
        f"{base_url}?slug={slug}",
        f"{base_url}/{slug}"
    ]

    valid_urls = []
    for url in urls:
        if check_url_exists(url):
            valid_urls.append(url)

    return {
        'slug': slug,
        'valid_urls': valid_urls,
        'valid': len(valid_urls) > 0
    }

def save_results_xml(results, timestamp):
    """Save results to an XML file"""
    root = ET.Element("rwa_claim_urls")

    metadata = ET.SubElement(root, "metadata")
    ET.SubElement(metadata, "timestamp").text = timestamp
    ET.SubElement(metadata, "total_projects").text = str(len(results))
    ET.SubElement(metadata, "valid_projects").text = str(len([r for r in results if r['valid']]))

    projects = ET.SubElement(root, "projects")
    for result in results:
        project = ET.SubElement(projects, "project")
        ET.SubElement(project, "slug").text = result['slug']
        ET.SubElement(project, "valid").text = str(result['valid'])
        urls = ET.SubElement(project, "urls")
        for url in result['valid_urls']:
            ET.SubElement(urls, "url").text = url

    xml_str = minidom.parseString(ET.tostring(root)).toprettyxml(indent="  ")

    filename = f"rwa_claim_urls_{timestamp}.xml"
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(xml_str)
    print(f"Results saved to {filename}")

def save_results_txt(results, timestamp):
    """Save results to a TXT file"""
    filename = f"rwa_claim_urls_{timestamp}.txt"
    with open(filename, 'w', encoding='utf-8') as f:
        f.write("RWA.io Claim URLs Results\n")
        f.write("=" * 50 + "\n\n")
        f.write(f"Timestamp: {timestamp}\n")
        f.write(f"Total projects checked: {len(results)}\n")
        f.write(f"Projects with valid claim URLs: {len([r for r in results if r['valid']])}\n\n")
        f.write("Valid Claim URLs by Project:\n")
        f.write("-" * 50 + "\n\n")

        for result in results:
            if result['valid']:
                f.write(f"Project: {result['slug']}\n")
                for url in result['valid_urls']:
                    f.write(f"  {url}\n")
                f.write("\n")
    print(f"Results saved to {filename}")

def process_slugs(slugs):
    """Process all slugs with threading and rate limiting"""
    results = []
    total = len(slugs)
    processed = 0

    print(f"Starting to check {total} projects...")
    start_time = time.time()
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')

    with ThreadPoolExecutor(max_workers=5) as executor:
        future_to_slug = {executor.submit(check_project, slug): slug for slug in slugs}

        for future in as_completed(future_to_slug):
            result = future.result()
            results.append(result)
            processed += 1

            if processed % 10 == 0 or processed == total:
                print(f"Processed {processed}/{total} projects ({(processed/total)*100:.1f}%)")

            if processed % 20 == 0 or processed == total:
                save_results_xml(results, timestamp)
                save_results_txt(results, timestamp)

            time.sleep(0.5)

    end_time = time.time()
    print(f"\nProcessing completed in {end_time - start_time:.1f} seconds")
    return results, timestamp

def print_summary(results):
    """Print summary of results"""
    valid_projects = [r for r in results if r['valid']]

    print("\n=== Results Summary ===")
    print(f"Total projects checked: {len(results)}")
    print(f"Projects with valid claim URLs: {len(valid_projects)}")

    print("\nValid claim URLs found:")
    for project in valid_projects:
        print(f"\nProject: {project['slug']}")
        for url in project['valid_urls']:
            print(f"  {url}")

def main():
    # Complete list of 206 slugs
    slugs = [
        "re.al", "bricksestate", "imo", "contracoin", "usp", "monerium-eur-emoney",
        "euroe-stablecoin", "stasis-euro", "gyen", "xsgd", "bilira", "gho",
        "binance-peg-busd", "gemini-dollar", "frax", "first-digital-usd", "usdc",
        "tether---usdt", "franklin-templeton-benji-investments", "midas", "opentrade",
        "yieldteq", "wisdomtree", "comtech-gold", "helix-finance", "vivacity-finance",
        "damm-finance", "union-protocol", "wildcat-protocol", "digift", "fortunafi",
        "lofty", "hashnote-usyc", "mountain-protocol", "superstate", "realt-tokens",
        "stusdt", "maker-rwa", "ethena", "solid-world", "tprotocol", "invar-finance",
        "sailing-protocol", "kuma-protocol", "danogo", "gold-dao", "binaryx-platform",
        "hiyield", "fundnel-alta", "merj", "1x.exchange", "hex-trust", "addx",
        "investa-x", "fusang", "upvest", "sygnum", "seba-bank", "mt-pelerin", "sdx",
        "stokr", "globacap", "copper", "21finance", "forge", "digishares", "tangany",
        "cashlink", "black-manta", "tokeny", "archax", "vertalo", "tzero",
        "texture-capital", "dtcc", "polymath", "fireblocks", "etana-custody",
        "consensys", "bitgo", "anchorage", "inx", "oasis-pro", "securitize", "hydrax",
        "apraemio", "redbelly-network", "crypto-autos.com", "diment.io",
        "gm-artification", "diamore", "emeraldco.io", "mantra", "particle",
        "yieldbricks", "dinari", "propbase", "realty-x", "rare-spirits", "cask-capital",
        "soil", "zoth.io", "cerchia", "bru.finance", "arca-labs", "alphaledger",
        "aktionariat", "carbify", "thovt", "plume-network", "xend-finance",
        "zambesi-gold", "decentralised-etf", "evident", "dovu", "futu", "bsos",
        "mansa-finance", "trendx", "the-rwax", "artory", "libertum", "tiamonds",
        "trakx", "caskcoin", "templedao", "pax-gold", "realio", "strikex",
        "naos-finance", "weset.io", "labs-group", "chintai", "etherland", "bixos",
        "brickken", "lumishare", "baxunited-states", "stima", "landshare",
        "blocksquare", "boson", "ix-swap", "domani", "propchain", "stobox",
        "galileo-protocol", "regen-network", "opulous", "tokenfi", "alliance-block",
        "pendle", "creditcoin", "polymesh", "aurus", "untangled", "unikura", "truefi",
        "toucan-protocol", "tangible", "swarm", "solv-finance", "ribbon-lend",
        "purplefi", "polytrade-finance", "pearl-exchange", "parcl", "parabol-finance",
        "openeden", "ondo-finance", "obligate", "meld-gold", "matrixdock", "maple",
        "makerdao", "landx", "klimadao", "impactmarket", "huma-finance", "homecoin",
        "goldfinch", "frigg", "florence-finance", "fabrica", "ensuro", "elysia",
        "defyca", "dexstar", "defactor", "cogito-protocol", "credix", "credifi",
        "clearpool", "citadao", "centrifuge", "canza-finance", "bluejay-finance",
        "blockcellar", "bitbond", "backed-finance", "altendis", "artrade", "anzen",
        "alta", "amfi", "aconomy"
    ]

    # Process slugs and get results
    results, timestamp = process_slugs(slugs)

    # Save final results in both formats
    save_results_xml(results, timestamp)
    save_results_txt(results, timestamp)

    # Print summary
    print_summary(results)
    print("\nResults have been saved in both XML and TXT formats:")
    print(f"1. rwa_claim_urls_{timestamp}.xml")
    print(f"2. rwa_claim_urls_{timestamp}.txt")

if __name__ == "__main__":
    main()
# Out:
# Starting to check 206 projects...
# Processed 10/206 projects (4.9%)
# Processed 20/206 projects (9.7%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 30/206 projects (14.6%)
# Processed 40/206 projects (19.4%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 50/206 projects (24.3%)
# Processed 60/206 projects (29.1%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 70/206 projects (34.0%)
# Processed 80/206 projects (38.8%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 90/206 projects (43.7%)
# Processed 100/206 projects (48.5%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 110/206 projects (53.4%)
# Processed 120/206 projects (58.3%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 130/206 projects (63.1%)
# Processed 140/206 projects (68.0%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 150/206 projects (72.8%)
# Processed 160/206 projects (77.7%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 170/206 projects (82.5%)
# Processed 180/206 projects (87.4%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 190/206 projects (92.2%)
# Processed 200/206 projects (97.1%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
# Processed 206/206 projects (100.0%)
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
#
# Processing completed in 104.3 seconds
# Results saved to rwa_claim_urls_20241029_211501.xml
# Results saved to rwa_claim_urls_20241029_211501.txt
#
# === Results Summary ===
# Total projects checked: 206
# Projects with valid claim URLs: 206
#
# Valid claim URLs found:
#
# Project: contracoin
#   https://insights.rwa.io/list-your-project/claim-project?slug=contracoin
#   https://insights.rwa.io/list-your-project/claim-project/contracoin
#
# Project: bricksestate
#   https://insights.rwa.io/list-your-project/claim-project?slug=bricksestate
#   https://insights.rwa.io/list-your-project/claim-project/bricksestate
#
# Project: re.al
#   https://insights.rwa.io/list-your-project/claim-project?slug=re.al
#   https://insights.rwa.io/list-your-project/claim-project/re.al
#
# Project: usp
#   https://insights.rwa.io/list-your-project/claim-project?slug=usp
#   https://insights.rwa.io/list-your-project/claim-project/usp
#
# Project: imo
#   https://insights.rwa.io/list-your-project/claim-project?slug=imo
#   https://insights.rwa.io/list-your-project/claim-project/imo
#
# Project: euroe-stablecoin
#   https://insights.rwa.io/list-your-project/claim-project?slug=euroe-stablecoin
#   https://insights.rwa.io/list-your-project/claim-project/euroe-stablecoin
#
# Project: gyen
#   https://insights.rwa.io/list-your-project/claim-project?slug=gyen
#   https://insights.rwa.io/list-your-project/claim-project/gyen
#
# Project: monerium-eur-emoney
#   https://insights.rwa.io/list-your-project/claim-project?slug=monerium-eur-emoney
#   https://insights.rwa.io/list-your-project/claim-project/monerium-eur-emoney
#
# Project: stasis-euro
#   https://insights.rwa.io/list-your-project/claim-project?slug=stasis-euro
#   https://insights.rwa.io/list-your-project/claim-project/stasis-euro
#
# Project: xsgd
#   https://insights.rwa.io/list-your-project/claim-project?slug=xsgd
#   https://insights.rwa.io/list-your-project/claim-project/xsgd
#
# Project: bilira
#   https://insights.rwa.io/list-your-project/claim-project?slug=bilira
#   https://insights.rwa.io/list-your-project/claim-project/bilira
#
# Project: gho
#   https://insights.rwa.io/list-your-project/claim-project?slug=gho
#   https://insights.rwa.io/list-your-project/claim-project/gho
#
# Project: binance-peg-busd
#   https://insights.rwa.io/list-your-project/claim-project?slug=binance-peg-busd
#   https://insights.rwa.io/list-your-project/claim-project/binance-peg-busd
#
# Project: gemini-dollar
#   https://insights.rwa.io/list-your-project/claim-project?slug=gemini-dollar
#   https://insights.rwa.io/list-your-project/claim-project/gemini-dollar
#
# Project: first-digital-usd
#   https://insights.rwa.io/list-your-project/claim-project?slug=first-digital-usd
#   https://insights.rwa.io/list-your-project/claim-project/first-digital-usd
#
# Project: tether---usdt
#   https://insights.rwa.io/list-your-project/claim-project?slug=tether---usdt
#   https://insights.rwa.io/list-your-project/claim-project/tether---usdt
#
# Project: usdc
#   https://insights.rwa.io/list-your-project/claim-project?slug=usdc
#   https://insights.rwa.io/list-your-project/claim-project/usdc
#
# Project: franklin-templeton-benji-investments
#   https://insights.rwa.io/list-your-project/claim-project?slug=franklin-templeton-benji-investments
#   https://insights.rwa.io/list-your-project/claim-project/franklin-templeton-benji-investments
#
# Project: frax
#   https://insights.rwa.io/list-your-project/claim-project?slug=frax
#   https://insights.rwa.io/list-your-project/claim-project/frax
#
# Project: yieldteq
#   https://insights.rwa.io/list-your-project/claim-project?slug=yieldteq
#   https://insights.rwa.io/list-your-project/claim-project/yieldteq
#
# Project: midas
#   https://insights.rwa.io/list-your-project/claim-project?slug=midas
#   https://insights.rwa.io/list-your-project/claim-project/midas
#
# Project: opentrade
#   https://insights.rwa.io/list-your-project/claim-project?slug=opentrade
#   https://insights.rwa.io/list-your-project/claim-project/opentrade
#
# Project: wisdomtree
#   https://insights.rwa.io/list-your-project/claim-project?slug=wisdomtree
#   https://insights.rwa.io/list-your-project/claim-project/wisdomtree
#
# Project: comtech-gold
#   https://insights.rwa.io/list-your-project/claim-project?slug=comtech-gold
#   https://insights.rwa.io/list-your-project/claim-project/comtech-gold
#
# Project: damm-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=damm-finance
#   https://insights.rwa.io/list-your-project/claim-project/damm-finance
#
# Project: helix-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=helix-finance
#   https://insights.rwa.io/list-your-project/claim-project/helix-finance
#
# Project: vivacity-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=vivacity-finance
#   https://insights.rwa.io/list-your-project/claim-project/vivacity-finance
#
# Project: union-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=union-protocol
#   https://insights.rwa.io/list-your-project/claim-project/union-protocol
#
# Project: wildcat-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=wildcat-protocol
#   https://insights.rwa.io/list-your-project/claim-project/wildcat-protocol
#
# Project: digift
#   https://insights.rwa.io/list-your-project/claim-project?slug=digift
#   https://insights.rwa.io/list-your-project/claim-project/digift
#
# Project: fortunafi
#   https://insights.rwa.io/list-your-project/claim-project?slug=fortunafi
#   https://insights.rwa.io/list-your-project/claim-project/fortunafi
#
# Project: lofty
#   https://insights.rwa.io/list-your-project/claim-project?slug=lofty
#   https://insights.rwa.io/list-your-project/claim-project/lofty
#
# Project: hashnote-usyc
#   https://insights.rwa.io/list-your-project/claim-project?slug=hashnote-usyc
#   https://insights.rwa.io/list-your-project/claim-project/hashnote-usyc
#
# Project: mountain-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=mountain-protocol
#   https://insights.rwa.io/list-your-project/claim-project/mountain-protocol
#
# Project: realt-tokens
#   https://insights.rwa.io/list-your-project/claim-project?slug=realt-tokens
#   https://insights.rwa.io/list-your-project/claim-project/realt-tokens
#
# Project: superstate
#   https://insights.rwa.io/list-your-project/claim-project?slug=superstate
#   https://insights.rwa.io/list-your-project/claim-project/superstate
#
# Project: stusdt
#   https://insights.rwa.io/list-your-project/claim-project?slug=stusdt
#   https://insights.rwa.io/list-your-project/claim-project/stusdt
#
# Project: ethena
#   https://insights.rwa.io/list-your-project/claim-project?slug=ethena
#   https://insights.rwa.io/list-your-project/claim-project/ethena
#
# Project: maker-rwa
#   https://insights.rwa.io/list-your-project/claim-project?slug=maker-rwa
#   https://insights.rwa.io/list-your-project/claim-project/maker-rwa
#
# Project: solid-world
#   https://insights.rwa.io/list-your-project/claim-project?slug=solid-world
#   https://insights.rwa.io/list-your-project/claim-project/solid-world
#
# Project: tprotocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=tprotocol
#   https://insights.rwa.io/list-your-project/claim-project/tprotocol
#
# Project: invar-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=invar-finance
#   https://insights.rwa.io/list-your-project/claim-project/invar-finance
#
# Project: kuma-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=kuma-protocol
#   https://insights.rwa.io/list-your-project/claim-project/kuma-protocol
#
# Project: sailing-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=sailing-protocol
#   https://insights.rwa.io/list-your-project/claim-project/sailing-protocol
#
# Project: danogo
#   https://insights.rwa.io/list-your-project/claim-project?slug=danogo
#   https://insights.rwa.io/list-your-project/claim-project/danogo
#
# Project: gold-dao
#   https://insights.rwa.io/list-your-project/claim-project?slug=gold-dao
#   https://insights.rwa.io/list-your-project/claim-project/gold-dao
#
# Project: binaryx-platform
#   https://insights.rwa.io/list-your-project/claim-project?slug=binaryx-platform
#   https://insights.rwa.io/list-your-project/claim-project/binaryx-platform
#
# Project: hiyield
#   https://insights.rwa.io/list-your-project/claim-project?slug=hiyield
#   https://insights.rwa.io/list-your-project/claim-project/hiyield
#
# Project: fundnel-alta
#   https://insights.rwa.io/list-your-project/claim-project?slug=fundnel-alta
#   https://insights.rwa.io/list-your-project/claim-project/fundnel-alta
#
# Project: merj
#   https://insights.rwa.io/list-your-project/claim-project?slug=merj
#   https://insights.rwa.io/list-your-project/claim-project/merj
#
# Project: 1x.exchange
#   https://insights.rwa.io/list-your-project/claim-project?slug=1x.exchange
#   https://insights.rwa.io/list-your-project/claim-project/1x.exchange
#
# Project: hex-trust
#   https://insights.rwa.io/list-your-project/claim-project?slug=hex-trust
#   https://insights.rwa.io/list-your-project/claim-project/hex-trust
#
# Project: addx
#   https://insights.rwa.io/list-your-project/claim-project?slug=addx
#   https://insights.rwa.io/list-your-project/claim-project/addx
#
# Project: investa-x
#   https://insights.rwa.io/list-your-project/claim-project?slug=investa-x
#   https://insights.rwa.io/list-your-project/claim-project/investa-x
#
# Project: fusang
#   https://insights.rwa.io/list-your-project/claim-project?slug=fusang
#   https://insights.rwa.io/list-your-project/claim-project/fusang
#
# Project: sygnum
#   https://insights.rwa.io/list-your-project/claim-project?slug=sygnum
#   https://insights.rwa.io/list-your-project/claim-project/sygnum
#
# Project: upvest
#   https://insights.rwa.io/list-your-project/claim-project?slug=upvest
#   https://insights.rwa.io/list-your-project/claim-project/upvest
#
# Project: seba-bank
#   https://insights.rwa.io/list-your-project/claim-project?slug=seba-bank
#   https://insights.rwa.io/list-your-project/claim-project/seba-bank
#
# Project: mt-pelerin
#   https://insights.rwa.io/list-your-project/claim-project?slug=mt-pelerin
#   https://insights.rwa.io/list-your-project/claim-project/mt-pelerin
#
# Project: sdx
#   https://insights.rwa.io/list-your-project/claim-project?slug=sdx
#   https://insights.rwa.io/list-your-project/claim-project/sdx
#
# Project: stokr
#   https://insights.rwa.io/list-your-project/claim-project?slug=stokr
#   https://insights.rwa.io/list-your-project/claim-project/stokr
#
# Project: globacap
#   https://insights.rwa.io/list-your-project/claim-project?slug=globacap
#   https://insights.rwa.io/list-your-project/claim-project/globacap
#
# Project: copper
#   https://insights.rwa.io/list-your-project/claim-project?slug=copper
#   https://insights.rwa.io/list-your-project/claim-project/copper
#
# Project: 21finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=21finance
#   https://insights.rwa.io/list-your-project/claim-project/21finance
#
# Project: forge
#   https://insights.rwa.io/list-your-project/claim-project?slug=forge
#   https://insights.rwa.io/list-your-project/claim-project/forge
#
# Project: digishares
#   https://insights.rwa.io/list-your-project/claim-project?slug=digishares
#   https://insights.rwa.io/list-your-project/claim-project/digishares
#
# Project: tangany
#   https://insights.rwa.io/list-your-project/claim-project?slug=tangany
#   https://insights.rwa.io/list-your-project/claim-project/tangany
#
# Project: cashlink
#   https://insights.rwa.io/list-your-project/claim-project?slug=cashlink
#   https://insights.rwa.io/list-your-project/claim-project/cashlink
#
# Project: black-manta
#   https://insights.rwa.io/list-your-project/claim-project?slug=black-manta
#   https://insights.rwa.io/list-your-project/claim-project/black-manta
#
# Project: archax
#   https://insights.rwa.io/list-your-project/claim-project?slug=archax
#   https://insights.rwa.io/list-your-project/claim-project/archax
#
# Project: vertalo
#   https://insights.rwa.io/list-your-project/claim-project?slug=vertalo
#   https://insights.rwa.io/list-your-project/claim-project/vertalo
#
# Project: tzero
#   https://insights.rwa.io/list-your-project/claim-project?slug=tzero
#   https://insights.rwa.io/list-your-project/claim-project/tzero
#
# Project: texture-capital
#   https://insights.rwa.io/list-your-project/claim-project?slug=texture-capital
#   https://insights.rwa.io/list-your-project/claim-project/texture-capital
#
# Project: tokeny
#   https://insights.rwa.io/list-your-project/claim-project?slug=tokeny
#   https://insights.rwa.io/list-your-project/claim-project/tokeny
#
# Project: dtcc
#   https://insights.rwa.io/list-your-project/claim-project?slug=dtcc
#   https://insights.rwa.io/list-your-project/claim-project/dtcc
#
# Project: fireblocks
#   https://insights.rwa.io/list-your-project/claim-project?slug=fireblocks
#   https://insights.rwa.io/list-your-project/claim-project/fireblocks
#
# Project: polymath
#   https://insights.rwa.io/list-your-project/claim-project?slug=polymath
#   https://insights.rwa.io/list-your-project/claim-project/polymath
#
# Project: etana-custody
#   https://insights.rwa.io/list-your-project/claim-project?slug=etana-custody
#   https://insights.rwa.io/list-your-project/claim-project/etana-custody
#
# Project: consensys
#   https://insights.rwa.io/list-your-project/claim-project?slug=consensys
#   https://insights.rwa.io/list-your-project/claim-project/consensys
#
# Project: bitgo
#   https://insights.rwa.io/list-your-project/claim-project?slug=bitgo
#   https://insights.rwa.io/list-your-project/claim-project/bitgo
#
# Project: inx
#   https://insights.rwa.io/list-your-project/claim-project?slug=inx
#   https://insights.rwa.io/list-your-project/claim-project/inx
#
# Project: oasis-pro
#   https://insights.rwa.io/list-your-project/claim-project?slug=oasis-pro
#   https://insights.rwa.io/list-your-project/claim-project/oasis-pro
#
# Project: anchorage
#   https://insights.rwa.io/list-your-project/claim-project?slug=anchorage
#   https://insights.rwa.io/list-your-project/claim-project/anchorage
#
# Project: securitize
#   https://insights.rwa.io/list-your-project/claim-project?slug=securitize
#   https://insights.rwa.io/list-your-project/claim-project/securitize
#
# Project: hydrax
#   https://insights.rwa.io/list-your-project/claim-project?slug=hydrax
#   https://insights.rwa.io/list-your-project/claim-project/hydrax
#
# Project: apraemio
#   https://insights.rwa.io/list-your-project/claim-project?slug=apraemio
#   https://insights.rwa.io/list-your-project/claim-project/apraemio
#
# Project: crypto-autos.com
#   https://insights.rwa.io/list-your-project/claim-project?slug=crypto-autos.com
#   https://insights.rwa.io/list-your-project/claim-project/crypto-autos.com
#
# Project: redbelly-network
#   https://insights.rwa.io/list-your-project/claim-project?slug=redbelly-network
#   https://insights.rwa.io/list-your-project/claim-project/redbelly-network
#
# Project: diment.io
#   https://insights.rwa.io/list-your-project/claim-project?slug=diment.io
#   https://insights.rwa.io/list-your-project/claim-project/diment.io
#
# Project: gm-artification
#   https://insights.rwa.io/list-your-project/claim-project?slug=gm-artification
#   https://insights.rwa.io/list-your-project/claim-project/gm-artification
#
# Project: diamore
#   https://insights.rwa.io/list-your-project/claim-project?slug=diamore
#   https://insights.rwa.io/list-your-project/claim-project/diamore
#
# Project: mantra
#   https://insights.rwa.io/list-your-project/claim-project?slug=mantra
#   https://insights.rwa.io/list-your-project/claim-project/mantra
#
# Project: emeraldco.io
#   https://insights.rwa.io/list-your-project/claim-project?slug=emeraldco.io
#   https://insights.rwa.io/list-your-project/claim-project/emeraldco.io
#
# Project: particle
#   https://insights.rwa.io/list-your-project/claim-project?slug=particle
#   https://insights.rwa.io/list-your-project/claim-project/particle
#
# Project: yieldbricks
#   https://insights.rwa.io/list-your-project/claim-project?slug=yieldbricks
#   https://insights.rwa.io/list-your-project/claim-project/yieldbricks
#
# Project: dinari
#   https://insights.rwa.io/list-your-project/claim-project?slug=dinari
#   https://insights.rwa.io/list-your-project/claim-project/dinari
#
# Project: realty-x
#   https://insights.rwa.io/list-your-project/claim-project?slug=realty-x
#   https://insights.rwa.io/list-your-project/claim-project/realty-x
#
# Project: propbase
#   https://insights.rwa.io/list-your-project/claim-project?slug=propbase
#   https://insights.rwa.io/list-your-project/claim-project/propbase
#
# Project: rare-spirits
#   https://insights.rwa.io/list-your-project/claim-project?slug=rare-spirits
#   https://insights.rwa.io/list-your-project/claim-project/rare-spirits
#
# Project: cask-capital
#   https://insights.rwa.io/list-your-project/claim-project?slug=cask-capital
#   https://insights.rwa.io/list-your-project/claim-project/cask-capital
#
# Project: soil
#   https://insights.rwa.io/list-your-project/claim-project?slug=soil
#   https://insights.rwa.io/list-your-project/claim-project/soil
#
# Project: zoth.io
#   https://insights.rwa.io/list-your-project/claim-project?slug=zoth.io
#   https://insights.rwa.io/list-your-project/claim-project/zoth.io
#
# Project: bru.finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=bru.finance
#   https://insights.rwa.io/list-your-project/claim-project/bru.finance
#
# Project: cerchia
#   https://insights.rwa.io/list-your-project/claim-project?slug=cerchia
#   https://insights.rwa.io/list-your-project/claim-project/cerchia
#
# Project: arca-labs
#   https://insights.rwa.io/list-your-project/claim-project?slug=arca-labs
#   https://insights.rwa.io/list-your-project/claim-project/arca-labs
#
# Project: alphaledger
#   https://insights.rwa.io/list-your-project/claim-project?slug=alphaledger
#   https://insights.rwa.io/list-your-project/claim-project/alphaledger
#
# Project: aktionariat
#   https://insights.rwa.io/list-your-project/claim-project?slug=aktionariat
#   https://insights.rwa.io/list-your-project/claim-project/aktionariat
#
# Project: carbify
#   https://insights.rwa.io/list-your-project/claim-project?slug=carbify
#   https://insights.rwa.io/list-your-project/claim-project/carbify
#
# Project: thovt
#   https://insights.rwa.io/list-your-project/claim-project?slug=thovt
#   https://insights.rwa.io/list-your-project/claim-project/thovt
#
# Project: xend-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=xend-finance
#   https://insights.rwa.io/list-your-project/claim-project/xend-finance
#
# Project: plume-network
#   https://insights.rwa.io/list-your-project/claim-project?slug=plume-network
#   https://insights.rwa.io/list-your-project/claim-project/plume-network
#
# Project: zambesi-gold
#   https://insights.rwa.io/list-your-project/claim-project?slug=zambesi-gold
#   https://insights.rwa.io/list-your-project/claim-project/zambesi-gold
#
# Project: decentralised-etf
#   https://insights.rwa.io/list-your-project/claim-project?slug=decentralised-etf
#   https://insights.rwa.io/list-your-project/claim-project/decentralised-etf
#
# Project: evident
#   https://insights.rwa.io/list-your-project/claim-project?slug=evident
#   https://insights.rwa.io/list-your-project/claim-project/evident
#
# Project: dovu
#   https://insights.rwa.io/list-your-project/claim-project?slug=dovu
#   https://insights.rwa.io/list-your-project/claim-project/dovu
#
# Project: futu
#   https://insights.rwa.io/list-your-project/claim-project?slug=futu
#   https://insights.rwa.io/list-your-project/claim-project/futu
#
# Project: bsos
#   https://insights.rwa.io/list-your-project/claim-project?slug=bsos
#   https://insights.rwa.io/list-your-project/claim-project/bsos
#
# Project: mansa-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=mansa-finance
#   https://insights.rwa.io/list-your-project/claim-project/mansa-finance
#
# Project: trendx
#   https://insights.rwa.io/list-your-project/claim-project?slug=trendx
#   https://insights.rwa.io/list-your-project/claim-project/trendx
#
# Project: the-rwax
#   https://insights.rwa.io/list-your-project/claim-project?slug=the-rwax
#   https://insights.rwa.io/list-your-project/claim-project/the-rwax
#
# Project: artory
#   https://insights.rwa.io/list-your-project/claim-project?slug=artory
#   https://insights.rwa.io/list-your-project/claim-project/artory
#
# Project: libertum
#   https://insights.rwa.io/list-your-project/claim-project?slug=libertum
#   https://insights.rwa.io/list-your-project/claim-project/libertum
#
# Project: tiamonds
#   https://insights.rwa.io/list-your-project/claim-project?slug=tiamonds
#   https://insights.rwa.io/list-your-project/claim-project/tiamonds
#
# Project: trakx
#   https://insights.rwa.io/list-your-project/claim-project?slug=trakx
#   https://insights.rwa.io/list-your-project/claim-project/trakx
#
# Project: caskcoin
#   https://insights.rwa.io/list-your-project/claim-project?slug=caskcoin
#   https://insights.rwa.io/list-your-project/claim-project/caskcoin
#
# Project: pax-gold
#   https://insights.rwa.io/list-your-project/claim-project?slug=pax-gold
#   https://insights.rwa.io/list-your-project/claim-project/pax-gold
#
# Project: templedao
#   https://insights.rwa.io/list-your-project/claim-project?slug=templedao
#   https://insights.rwa.io/list-your-project/claim-project/templedao
#
# Project: realio
#   https://insights.rwa.io/list-your-project/claim-project?slug=realio
#   https://insights.rwa.io/list-your-project/claim-project/realio
#
# Project: strikex
#   https://insights.rwa.io/list-your-project/claim-project?slug=strikex
#   https://insights.rwa.io/list-your-project/claim-project/strikex
#
# Project: weset.io
#   https://insights.rwa.io/list-your-project/claim-project?slug=weset.io
#   https://insights.rwa.io/list-your-project/claim-project/weset.io
#
# Project: naos-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=naos-finance
#   https://insights.rwa.io/list-your-project/claim-project/naos-finance
#
# Project: labs-group
#   https://insights.rwa.io/list-your-project/claim-project?slug=labs-group
#   https://insights.rwa.io/list-your-project/claim-project/labs-group
#
# Project: chintai
#   https://insights.rwa.io/list-your-project/claim-project?slug=chintai
#   https://insights.rwa.io/list-your-project/claim-project/chintai
#
# Project: etherland
#   https://insights.rwa.io/list-your-project/claim-project?slug=etherland
#   https://insights.rwa.io/list-your-project/claim-project/etherland
#
# Project: lumishare
#   https://insights.rwa.io/list-your-project/claim-project?slug=lumishare
#   https://insights.rwa.io/list-your-project/claim-project/lumishare
#
# Project: baxunited-states
#   https://insights.rwa.io/list-your-project/claim-project?slug=baxunited-states
#   https://insights.rwa.io/list-your-project/claim-project/baxunited-states
#
# Project: brickken
#   https://insights.rwa.io/list-your-project/claim-project?slug=brickken
#   https://insights.rwa.io/list-your-project/claim-project/brickken
#
# Project: bixos
#   https://insights.rwa.io/list-your-project/claim-project?slug=bixos
#   https://insights.rwa.io/list-your-project/claim-project/bixos
#
# Project: stima
#   https://insights.rwa.io/list-your-project/claim-project?slug=stima
#   https://insights.rwa.io/list-your-project/claim-project/stima
#
# Project: landshare
#   https://insights.rwa.io/list-your-project/claim-project?slug=landshare
#   https://insights.rwa.io/list-your-project/claim-project/landshare
#
# Project: blocksquare
#   https://insights.rwa.io/list-your-project/claim-project?slug=blocksquare
#   https://insights.rwa.io/list-your-project/claim-project/blocksquare
#
# Project: boson
#   https://insights.rwa.io/list-your-project/claim-project?slug=boson
#   https://insights.rwa.io/list-your-project/claim-project/boson
#
# Project: ix-swap
#   https://insights.rwa.io/list-your-project/claim-project?slug=ix-swap
#   https://insights.rwa.io/list-your-project/claim-project/ix-swap
#
# Project: domani
#   https://insights.rwa.io/list-your-project/claim-project?slug=domani
#   https://insights.rwa.io/list-your-project/claim-project/domani
#
# Project: propchain
#   https://insights.rwa.io/list-your-project/claim-project?slug=propchain
#   https://insights.rwa.io/list-your-project/claim-project/propchain
#
# Project: stobox
#   https://insights.rwa.io/list-your-project/claim-project?slug=stobox
#   https://insights.rwa.io/list-your-project/claim-project/stobox
#
# Project: galileo-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=galileo-protocol
#   https://insights.rwa.io/list-your-project/claim-project/galileo-protocol
#
# Project: regen-network
#   https://insights.rwa.io/list-your-project/claim-project?slug=regen-network
#   https://insights.rwa.io/list-your-project/claim-project/regen-network
#
# Project: opulous
#   https://insights.rwa.io/list-your-project/claim-project?slug=opulous
#   https://insights.rwa.io/list-your-project/claim-project/opulous
#
# Project: alliance-block
#   https://insights.rwa.io/list-your-project/claim-project?slug=alliance-block
#   https://insights.rwa.io/list-your-project/claim-project/alliance-block
#
# Project: pendle
#   https://insights.rwa.io/list-your-project/claim-project?slug=pendle
#   https://insights.rwa.io/list-your-project/claim-project/pendle
#
# Project: creditcoin
#   https://insights.rwa.io/list-your-project/claim-project?slug=creditcoin
#   https://insights.rwa.io/list-your-project/claim-project/creditcoin
#
# Project: tokenfi
#   https://insights.rwa.io/list-your-project/claim-project?slug=tokenfi
#   https://insights.rwa.io/list-your-project/claim-project/tokenfi
#
# Project: polymesh
#   https://insights.rwa.io/list-your-project/claim-project?slug=polymesh
#   https://insights.rwa.io/list-your-project/claim-project/polymesh
#
# Project: untangled
#   https://insights.rwa.io/list-your-project/claim-project?slug=untangled
#   https://insights.rwa.io/list-your-project/claim-project/untangled
#
# Project: aurus
#   https://insights.rwa.io/list-your-project/claim-project?slug=aurus
#   https://insights.rwa.io/list-your-project/claim-project/aurus
#
# Project: unikura
#   https://insights.rwa.io/list-your-project/claim-project?slug=unikura
#   https://insights.rwa.io/list-your-project/claim-project/unikura
#
# Project: truefi
#   https://insights.rwa.io/list-your-project/claim-project?slug=truefi
#   https://insights.rwa.io/list-your-project/claim-project/truefi
#
# Project: toucan-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=toucan-protocol
#   https://insights.rwa.io/list-your-project/claim-project/toucan-protocol
#
# Project: tangible
#   https://insights.rwa.io/list-your-project/claim-project?slug=tangible
#   https://insights.rwa.io/list-your-project/claim-project/tangible
#
# Project: swarm
#   https://insights.rwa.io/list-your-project/claim-project?slug=swarm
#   https://insights.rwa.io/list-your-project/claim-project/swarm
#
# Project: ribbon-lend
#   https://insights.rwa.io/list-your-project/claim-project?slug=ribbon-lend
#   https://insights.rwa.io/list-your-project/claim-project/ribbon-lend
#
# Project: solv-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=solv-finance
#   https://insights.rwa.io/list-your-project/claim-project/solv-finance
#
# Project: purplefi
#   https://insights.rwa.io/list-your-project/claim-project?slug=purplefi
#   https://insights.rwa.io/list-your-project/claim-project/purplefi
#
# Project: pearl-exchange
#   https://insights.rwa.io/list-your-project/claim-project?slug=pearl-exchange
#   https://insights.rwa.io/list-your-project/claim-project/pearl-exchange
#
# Project: parcl
#   https://insights.rwa.io/list-your-project/claim-project?slug=parcl
#   https://insights.rwa.io/list-your-project/claim-project/parcl
#
# Project: polytrade-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=polytrade-finance
#   https://insights.rwa.io/list-your-project/claim-project/polytrade-finance
#
# Project: parabol-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=parabol-finance
#   https://insights.rwa.io/list-your-project/claim-project/parabol-finance
#
# Project: openeden
#   https://insights.rwa.io/list-your-project/claim-project?slug=openeden
#   https://insights.rwa.io/list-your-project/claim-project/openeden
#
# Project: meld-gold
#   https://insights.rwa.io/list-your-project/claim-project?slug=meld-gold
#   https://insights.rwa.io/list-your-project/claim-project/meld-gold
#
# Project: obligate
#   https://insights.rwa.io/list-your-project/claim-project?slug=obligate
#   https://insights.rwa.io/list-your-project/claim-project/obligate
#
# Project: ondo-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=ondo-finance
#   https://insights.rwa.io/list-your-project/claim-project/ondo-finance
#
# Project: matrixdock
#   https://insights.rwa.io/list-your-project/claim-project?slug=matrixdock
#   https://insights.rwa.io/list-your-project/claim-project/matrixdock
#
# Project: maple
#   https://insights.rwa.io/list-your-project/claim-project?slug=maple
#   https://insights.rwa.io/list-your-project/claim-project/maple
#
# Project: landx
#   https://insights.rwa.io/list-your-project/claim-project?slug=landx
#   https://insights.rwa.io/list-your-project/claim-project/landx
#
# Project: makerdao
#   https://insights.rwa.io/list-your-project/claim-project?slug=makerdao
#   https://insights.rwa.io/list-your-project/claim-project/makerdao
#
# Project: impactmarket
#   https://insights.rwa.io/list-your-project/claim-project?slug=impactmarket
#   https://insights.rwa.io/list-your-project/claim-project/impactmarket
#
# Project: klimadao
#   https://insights.rwa.io/list-your-project/claim-project?slug=klimadao
#   https://insights.rwa.io/list-your-project/claim-project/klimadao
#
# Project: goldfinch
#   https://insights.rwa.io/list-your-project/claim-project?slug=goldfinch
#   https://insights.rwa.io/list-your-project/claim-project/goldfinch
#
# Project: homecoin
#   https://insights.rwa.io/list-your-project/claim-project?slug=homecoin
#   https://insights.rwa.io/list-your-project/claim-project/homecoin
#
# Project: huma-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=huma-finance
#   https://insights.rwa.io/list-your-project/claim-project/huma-finance
#
# Project: frigg
#   https://insights.rwa.io/list-your-project/claim-project?slug=frigg
#   https://insights.rwa.io/list-your-project/claim-project/frigg
#
# Project: florence-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=florence-finance
#   https://insights.rwa.io/list-your-project/claim-project/florence-finance
#
# Project: fabrica
#   https://insights.rwa.io/list-your-project/claim-project?slug=fabrica
#   https://insights.rwa.io/list-your-project/claim-project/fabrica
#
# Project: ensuro
#   https://insights.rwa.io/list-your-project/claim-project?slug=ensuro
#   https://insights.rwa.io/list-your-project/claim-project/ensuro
#
# Project: defyca
#   https://insights.rwa.io/list-your-project/claim-project?slug=defyca
#   https://insights.rwa.io/list-your-project/claim-project/defyca
#
# Project: dexstar
#   https://insights.rwa.io/list-your-project/claim-project?slug=dexstar
#   https://insights.rwa.io/list-your-project/claim-project/dexstar
#
# Project: elysia
#   https://insights.rwa.io/list-your-project/claim-project?slug=elysia
#   https://insights.rwa.io/list-your-project/claim-project/elysia
#
# Project: defactor
#   https://insights.rwa.io/list-your-project/claim-project?slug=defactor
#   https://insights.rwa.io/list-your-project/claim-project/defactor
#
# Project: credifi
#   https://insights.rwa.io/list-your-project/claim-project?slug=credifi
#   https://insights.rwa.io/list-your-project/claim-project/credifi
#
# Project: credix
#   https://insights.rwa.io/list-your-project/claim-project?slug=credix
#   https://insights.rwa.io/list-your-project/claim-project/credix
#
# Project: clearpool
#   https://insights.rwa.io/list-your-project/claim-project?slug=clearpool
#   https://insights.rwa.io/list-your-project/claim-project/clearpool
#
# Project: cogito-protocol
#   https://insights.rwa.io/list-your-project/claim-project?slug=cogito-protocol
#   https://insights.rwa.io/list-your-project/claim-project/cogito-protocol
#
# Project: citadao
#   https://insights.rwa.io/list-your-project/claim-project?slug=citadao
#   https://insights.rwa.io/list-your-project/claim-project/citadao
#
# Project: centrifuge
#   https://insights.rwa.io/list-your-project/claim-project?slug=centrifuge
#   https://insights.rwa.io/list-your-project/claim-project/centrifuge
#
# Project: canza-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=canza-finance
#   https://insights.rwa.io/list-your-project/claim-project/canza-finance
#
# Project: bluejay-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=bluejay-finance
#   https://insights.rwa.io/list-your-project/claim-project/bluejay-finance
#
# Project: blockcellar
#   https://insights.rwa.io/list-your-project/claim-project?slug=blockcellar
#   https://insights.rwa.io/list-your-project/claim-project/blockcellar
#
# Project: bitbond
#   https://insights.rwa.io/list-your-project/claim-project?slug=bitbond
#   https://insights.rwa.io/list-your-project/claim-project/bitbond
#
# Project: backed-finance
#   https://insights.rwa.io/list-your-project/claim-project?slug=backed-finance
#   https://insights.rwa.io/list-your-project/claim-project/backed-finance
#
# Project: altendis
#   https://insights.rwa.io/list-your-project/claim-project?slug=altendis
#   https://insights.rwa.io/list-your-project/claim-project/altendis
#
# Project: artrade
#   https://insights.rwa.io/list-your-project/claim-project?slug=artrade
#   https://insights.rwa.io/list-your-project/claim-project/artrade
#
# Project: anzen
#   https://insights.rwa.io/list-your-project/claim-project?slug=anzen
#   https://insights.rwa.io/list-your-project/claim-project/anzen
#
# Project: alta
#   https://insights.rwa.io/list-your-project/claim-project?slug=alta
#   https://insights.rwa.io/list-your-project/claim-project/alta
#
# Project: amfi
#   https://insights.rwa.io/list-your-project/claim-project?slug=amfi
#   https://insights.rwa.io/list-your-project/claim-project/amfi
#
# Project: aconomy
#   https://insights.rwa.io/list-your-project/claim-project?slug=aconomy
#   https://insights.rwa.io/list-your-project/claim-project/aconomy
#
# Results have been saved in both XML and TXT formats:
# 1. rwa_claim_urls_20241029_211501.xml
# 2. rwa_claim_urls_20241029_211501.txt
